# %%
PieChart[{1, 2, 5, 4}]
# Out:
# -Graphics-

# %%
Table[PieChart[{1, 1, 1}], 3]
# Out:
# {-Graphics-, -Graphics-, -Graphics-}

# %%
Table[Table[RandomColor[], 33]]
# Out:
# {RGBColor[0.164772, 0.842686, 0.62826], RGBColor[0.410693, 0.546112, 0.760553],
#
# >   RGBColor[0.886146, 0.530684, 0.551186], RGBColor[0.591844, 0.567617, 0.895719],
#
# >   RGBColor[0.0938667, 0.496255, 0.872966], RGBColor[0.515003, 0.392452, 0.17433],
#
# >   RGBColor[0.318751, 0.199454, 0.0898979], RGBColor[0.601997, 0.134547, 0.00936213],
#
# >   RGBColor[0.869991, 0.229861, 0.390481], RGBColor[0.147315, 0.895887, 0.566436],
#
# >   RGBColor[0.10019, 0.368717, 0.918614], RGBColor[0.29229, 0.778295, 0.79121],
#
# >   RGBColor[0.750402, 0.371687, 0.837544], RGBColor[0.391764, 0.630687, 0.0290108],
#
# >   RGBColor[0.980647, 0.173062, 0.502987], RGBColor[0.376199, 0.167493, 0.659945],
#
# >   RGBColor[0.0447998, 0.392647, 0.830065], RGBColor[0.842119, 0.804307, 0.490687],
#
# >   RGBColor[0.703872, 0.749125, 0.897609], RGBColor[0.423799, 0.0537244, 0.703043],
#
# >   RGBColor[0.551414, 0.945334, 0.749289], RGBColor[0.639453, 0.341451, 0.470749],
#
# ...

# %%
Graphics3D[Style[Sphere[], Yellow]]
# Out:
# -Graphics3D-

# %%
EdgeDetect[Rasterize[Style["ABC", 100]]]
# Out:
# -Image-

# %%
WolframAlpha["tell me a joke"]
# Out:
# DynamicNamespace[WolframAlphaQueryResults,
#
# >   DynamicModule[{Typeset`q = tell me a joke,
#
# >     Typeset`opts =
#
# >      {AppearanceElements ->
#
# >        {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources}},
#
# >     Typeset`elements =
#
# >      {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >     Typeset`pod1 =
#
# >      XMLElement[pod, {title -> Input interpretation, scanner -> Identity, id -> Input,
#
# >        position -> 100, error -> false, numsubpods -> 1},
#
# >       {XMLElement[subpod, {title -> },
#
# >         {XMLElement[cell, {compressed -> False, string -> True},
#
# >           {Cell[BoxData[FormBox[TagBox[FormBox[TagBox["Tell me a joke.", Identity],
#
# >                 TraditionalForm], PolynomialForm[#1, TraditionalOrder -> False] & ],
#
# >               TraditionalForm]], Output,
#
# >             {Background -> None, GraphicsBoxOptions ->
#
# ...

# %%
EntityList["Planet"]
# Out:
# {Entity[Planet, Mercury], Entity[Planet, Venus], Entity[Planet, Earth],
#
# >   Entity[Planet, Mars], Entity[Planet, Jupiter], Entity[Planet, Saturn],
#
# >   Entity[Planet, Uranus], Entity[Planet, Neptune]}

# %%
EntityValue["Planet", "Image"]
# Out:
# {-Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-, -Image-}

# %%
WolframAlpha["starry night"]["Image"]
# Out:
# DynamicNamespace[WolframAlphaQueryResults,
#
# >    DynamicModule[{Typeset`q = starry night,
#
# >      Typeset`opts =
#
# >       {AppearanceElements ->
#
# >         {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources}},
#
# >      Typeset`elements =
#
# >       {Warnings, Assumptions, Brand, Pods, PodMenus, Unsuccessful, Sources},
#
# >      Typeset`pod1 =
#
# >       XMLElement[pod, {title -> Input interpretation, scanner -> Identity,
#
# >         id -> Input, position -> 100, error -> false, numsubpods -> 1},
#
# >        {XMLElement[subpod, {title -> },
#
# >          {XMLElement[minput, {}, {Entity["Artwork",\
#
# >              "TheStarryNight::VincentVanGogh"]}],
#
# >           XMLElement[cell, {compressed -> False, string -> True},
#
# >            {Cell[BoxData[FormBox[TagBox[FormBox[StyleBox[TemplateBox[{
#
# >                     TagBox[TagBox["The Starry Night",
#
# >                       TagBoxWrapper[Entity ->
#
# ...

# %%
Rotate["Hello, World!", 35°]
# Out:
# Rotate[Hello, World!, 35 Degree]

# %%
NestList[Sqrt[1+#]&, 1, 5]
# Out:
# {1, Sqrt[2], Sqrt[1 + Sqrt[2]], Sqrt[1 + Sqrt[1 + Sqrt[2]]],
#
# >   Sqrt[1 + Sqrt[1 + Sqrt[1 + Sqrt[2]]]],
#
# >   Sqrt[1 + Sqrt[1 + Sqrt[1 + Sqrt[1 + Sqrt[2]]]]]}

# %%
EntityValue[Interpreter["Animal"][{ "cow", "tiger", "elephant"}], "Image"]
# Out:
# {-Image-, -Image-, -Image-}
